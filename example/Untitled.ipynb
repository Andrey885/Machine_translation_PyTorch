# %%
import numpy as np
# Out:
# array([[ -0.85348206,  15.67092971,   5.87596624, ...,  -6.08767256,
#          -7.23157254,  -8.36021816],
#        [-21.42422274,  16.09504536,   4.7767885 , ..., -10.7265327 ,
#         -11.82427747,   2.8693803 ],
#        [  8.57608724,  17.50351537,  14.72470202, ...,  13.63628098,
#          -9.53812879,   4.88894483],
#        ...,
#        [  1.60148855, -14.12666645,   5.59421529, ...,  -0.67663585,
#         -11.23318452,   1.03831162],
#        [ -9.10396225,   1.22572656,  14.64832278, ...,  -8.12719188,
#          -9.26502984,  -9.52172473],
#        [ 12.49400241,   6.60787564, -15.74738035, ...,  -8.15484275,
#           4.1125934 ,  12.90112948]])

# %%
import matplotlib.pyplot as plt
x = np.random.normal(1,10, (1000, 50))
plt.plot(x[:, 0])
